# %% [markdown]
# # Sample Data Analysis Notebook

# %%
import pandas as pd
import numpy as np

# %%
# Hardcoded path - should be detected
data_path = "/Users/sarah/data/customers.csv"
df = pd.read_csv(data_path)

# %%
# More hardcoded config values
epochs = 100
learning_rate = 0.001
batch_size = 32

# %%
# Data cleaning
df_cleaned = df.dropna()
df_cleaned.columns = df_cleaned.columns.str.lower()

# %%
# This cell has a dependency issue - uses df_cleaned from above
# but also uses scaler from below
X_scaled = scaler.transform(df_cleaned)

# %%
# Scaler defined here - but used above
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_cleaned)

# %%
# Model training
model_path = "./models/best_model.pkl"
results = {"accuracy": 0.95, "loss": 0.05}
